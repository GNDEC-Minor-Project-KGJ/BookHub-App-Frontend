# %% [markdown]
# ## Importing necessary packages

# %%
import pandas as pd
import numpy as np

# Graphic plotting
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Books dataset
books = pd.read_csv('GR-Books.csv')
books.columns = ['Desc', 'unamed', 'author', 'genre', 'url', 'rating', 'title']

# Dropping the unnamed column
books.drop('unamed', inplace=True, axis=1)

books.head()
# Out:
#                                                 Desc                author  \
# 0  We know that power is shifting: From West to E...           Moisés Naím
# 1  Following the success of The Accidental Billio...       Blake J. Harris
# 2  How to tap the power of social software and ne...          Chris Brogan
# 3  William J. Bernstein is an American financial ...  William J. Bernstein
# 4  Amazing book. And I joined Steve Jobs and many...           Akio Morita
#
#       genre                                                url  rating  \
# 0  Business  https://i.gr-assets.com/images/S/compressed.ph...    3.63
# 1  Business  https://i.gr-assets.com/images/S/compressed.ph...    3.94
# 2  Business  https://i.gr-assets.com/images/S/compressed.ph...    3.78
# 3  Business  https://i.gr-assets.com/images/S/compressed.ph...    4.20
# 4  Business  https://i.gr-assets.com/images/S/compressed.ph...    4.05
#
#                                                title
# 0  The End of Power: From Boardrooms to Battlefie...
# 1  Console Wars: Sega, Nintendo, and the Battle t...
# 2  Trust Agents: Using the Web to Build Influence...
# 3                      The Four Pillars of Investing
# 4                Made in Japan: Akio Morita and Sony

# %%
books
# Out:
#                                                    Desc                author  \
# 0     We know that power is shifting: From West to E...           Moisés Naím
# 1     Following the success of The Accidental Billio...       Blake J. Harris
# 2     How to tap the power of social software and ne...          Chris Brogan
# 3     William J. Bernstein is an American financial ...  William J. Bernstein
# 4     Amazing book. And I joined Steve Jobs and many...           Akio Morita
# ...                                                 ...                   ...
# 2446  Ralph Roberts, a sus setenta años y tras la mu...          Stephen King
# 2447  Murder at the Vicarage marks the debut of Agat...       Agatha Christie
# 2448  In 1951 John Wyndham published his novel The D...          John Wyndham
# 2449  This now classic book revealed Flannery O'Conn...     Flannery O'Connor
# 2450  Imbued on every page with Frank McCourt's asto...         Frank McCourt
#
#             genre                                                url  rating  \
# 0        Business  https://i.gr-assets.com/images/S/compressed.ph...    3.63
# 1        Business  https://i.gr-assets.com/images/S/compressed.ph...    3.94
# 2        Business  https://i.gr-assets.com/images/S/compressed.ph...    3.78
# 3        Business  https://i.gr-assets.com/images/S/compressed.ph...    4.20
# 4        Business  https://i.gr-assets.com/images/S/compressed.ph...    4.05
# ...           ...                                                ...     ...
# 2446  Non-Fiction  https://i.gr-assets.com/images/S/compressed.ph...    3.82
# 2447  Non-Fiction  https://i.gr-assets.com/images/S/compressed.ph...    4.05
# 2448  Non-Fiction  https://i.gr-assets.com/images/S/compressed.ph...    4.02
# 2449  Non-Fiction  https://i.gr-assets.com/images/S/compressed.ph...    4.22
# 2450  Non-Fiction  https://i.gr-assets.com/images/S/compressed.ph...    4.11
#
#                                                   title
# 0     The End of Power: From Boardrooms to Battlefie...
# 1     Console Wars: Sega, Nintendo, and the Battle t...
# 2     Trust Agents: Using the Web to Build Influence...
# 3                         The Four Pillars of Investing
# 4                   Made in Japan: Akio Morita and Sony
# ...                                                 ...
# 2446                                           Insomnia
# 2447                             Murder at the Vicarage
# 2448                            The Day of the Triffids
# 2449       A Good Man is Hard to Find and Other Stories
# 2450                                     Angela's Ashes
#
# [2382 rows x 6 columns]

# %%
# Covert dataframe to csv file
books.to_csv('Processed_Books.csv',index=False)

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 4650-E864
#
#  Directory of C:\Users\JasJap\OneDrive\Desktop\KGJ_Minor\Major_BookHub
#
# 15-10-2022  20:46    <DIR>          .
# 15-10-2022  20:38    <DIR>          ..
# 15-10-2022  20:40    <DIR>          .ipynb_checkpoints
# 15-10-2022  20:36         3,153,950 GR-Books.csv
# 15-10-2022  20:46         3,139,593 Processed_Books.csv
# 15-10-2022  20:45             5,932 SQL_Database.ipynb
#                3 File(s)      6,299,475 bytes
#                3 Dir(s)  210,945,843,200 bytes free
